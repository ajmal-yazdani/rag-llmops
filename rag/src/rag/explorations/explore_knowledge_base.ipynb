# %%
import lancedb

db = lancedb.connect("../knowledge_base")
db
# Out:
# LanceDBConnection(uri='c:\\AI\\rag-llmops\\rag\\src\\rag\\explorations\\..\\knowledge_base')

# %%
articles_table = db["articles"]
articles_table
# Out:
# LanceTable(name='articles', version=3, _conn=LanceDBConnection(uri='c:\\AI\\rag-llmops\\rag\\src\\rag\\explorations\\..\\knowledge_base'))

# %%
articles_table.to_pandas()
# Out:
#     document_name                                          filepath  \
# 0  1592999384.txt  C:\AI\rag-llmops\rag\src\rag\data\1592999384.txt
#
#                                              content  \
# 0   \n \n280+ Interesting Short Stories          ...
#
#                                            embedding
# 0  [0.017730713, -0.0013656616, 0.06616211, 0.052...

# %%
articles_table.to_pandas()["embedding"].iloc[0].shape
# Out:
# (1024,)
